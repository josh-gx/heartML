# %% [markdown]
# # Heart Disease Classification

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Heart-Disease-Classification" data-toc-modified-id="Heart-Disease-Classification-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Heart Disease Classification</a></span><ul class="toc-item"><li><span><a href="#Overview" data-toc-modified-id="Overview-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Overview</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Results</a></span></li></ul></li><li><span><a href="#Load-Libraries-and-Data" data-toc-modified-id="Load-Libraries-and-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load Libraries and Data</a></span><ul class="toc-item"><li><span><a href="#Inspect-Data" data-toc-modified-id="Inspect-Data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Inspect Data</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Examine-Continuous-Variables" data-toc-modified-id="Examine-Continuous-Variables-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Examine Continuous Variables</a></span></li><li><span><a href="#Examine-Categorical-Variables" data-toc-modified-id="Examine-Categorical-Variables-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Examine Categorical Variables</a></span></li><li><span><a href="#EDA-Findings" data-toc-modified-id="EDA-Findings-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>EDA Findings</a></span></li></ul></li><li><span><a href="#Model-Data-Preparation" data-toc-modified-id="Model-Data-Preparation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Model Data Preparation</a></span><ul class="toc-item"><li><span><a href="#Encode-Categorical-Variables" data-toc-modified-id="Encode-Categorical-Variables-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Encode Categorical Variables</a></span></li><li><span><a href="#Train-&amp;-Test-Data-Split" data-toc-modified-id="Train-&amp;-Test-Data-Split-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Train &amp; Test Data Split</a></span></li></ul></li><li><span><a href="#Machine-Learning" data-toc-modified-id="Machine-Learning-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Machine Learning</a></span><ul class="toc-item"><li><span><a href="#Logistic-Reggression" data-toc-modified-id="Logistic-Reggression-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Logistic Reggression</a></span><ul class="toc-item"><li><span><a href="#Classification-Report" data-toc-modified-id="Classification-Report-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Classification Report</a></span></li><li><span><a href="#Confusion-Matrix" data-toc-modified-id="Confusion-Matrix-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Confusion Matrix</a></span></li><li><span><a href="#ROC-&amp;-AUC" data-toc-modified-id="ROC-&amp;-AUC-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>ROC &amp; AUC</a></span></li></ul></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Random Forest</a></span><ul class="toc-item"><li><span><a href="#Classification-Report" data-toc-modified-id="Classification-Report-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Classification Report</a></span></li><li><span><a href="#Confusion-Matrix" data-toc-modified-id="Confusion-Matrix-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Confusion Matrix</a></span></li><li><span><a href="#ROC-&amp;-AUC" data-toc-modified-id="ROC-&amp;-AUC-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>ROC &amp; AUC</a></span></li></ul></li></ul></li><li><span><a href="#Results-Summary" data-toc-modified-id="Results-Summary-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Results Summary</a></span><ul class="toc-item"><li><span><a href="#70/30-Split-Performance-Summary" data-toc-modified-id="70/30-Split-Performance-Summary-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>70/30 Split Performance Summary</a></span></li><li><span><a href="#K-Fold-Performance" data-toc-modified-id="K-Fold-Performance-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>K-Fold Performance</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Overview

# %% [markdown]
# **Context**
#
# This database contains 76 attributes, but all published experiments refer to using a subset of 14 of them. In particular, the Cleveland database is the only one that has been used by ML researchers to this date.
#
# **Variables**
#
# 1. age  = in years
# 2. sex  = (1 = male; 0 = female)
# 3. cp  = chest pain type (4 values)
# 4. trestbps  = resting blood pressure in mm Hg
# 5. chol  = serum cholestoral in mg/dl
# 6. fbs  = fasting blood sugar > 120 mg/dl (1 = true; 0 = false)
# 7. restecg  = resting electrocardiographic results (values 0,1,2)
# 8. thalach  = maximum heart rate achieved
# 9. exang  = exercise induced angina (1 = yes; 0 = no)
# 10. oldpeak  = ST depression induced by exercise relative to rest
# 11. slope  = the slope of the peak exercise ST segment
# 12. ca  = number of major vessels (0-3) colored by flourosopy
# 13. thal  = thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
# 14. **target  = presence of heart disease (1 = true; 0 = false)**
#
# **Creators**
# 1. Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D.
# 2. University Hospital, Zurich, Switzerland: William Steinbrunn, M.D.
# 3. University Hospital, Basel, Switzerland: Matthias Pfisterer, M.D.
# 4. V.A. Medical Center, Long Beach and Cleveland Clinic Foundation: Robert Detrano, M.D., Ph.D.
#
# Data Source: https://www.kaggle.com/ronitf/heart-disease-uci

# %% [markdown]
# ## Results
#
# **Objecive:** Classify patients for presence of heart disease
#
# ** Approach:** Use Machine Learning to bifrocate patients for target
#
# **Experiment Models:** Logistic Regression and Random Forest 70/30 Train Test Split
#
# ** Experiment Best Results: **
# **Logistic Regression**
# * 88-90% Accuracy
# * 88-90% Precision
# * 92-94% Recall
# * 88-90% AUC
# * 85-95% Cross Validaiton (k-10)

# %% [markdown]
# # Load Libraries and Data

# %%
import numpy as np # cals and arrays
import pandas as pd # data frames
import matplotlib.pyplot as plt # plots
import seaborn as sns # plots
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore") # some show for seaborn

# %%
df = pd.read_csv('heart.csv') # load data

# %% [markdown]
# ## Inspect Data

# %%
print('Total Nulls:\n', df.isnull().sum()) # check for nulls
print('Total Columns: ', len(df.columns)) # colum count
# Out:
# Total Nulls:
#  age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64
# Total Columns:  14

# %% [markdown]
# # EDA

# %%
# organize variables by numerical and categorical
vars_con = ['age', 'trestbps','chol', 'thalach', 'oldpeak']
vars_cat = ['sex', 'cp','fbs', 'restecg', 'exang', 
                    'slope','ca','thal','target' ]

# %%
# check split
print('Continious Variables: ', len(vars_con))
print('Categorical Variables: ', len(vars_cat))

total_check = len(vars_con)+ len(vars_cat)

print('Total Variables: ', total_check)

if total_check == len(df.columns):
    print('Variable Spilt Ties')
else:
    print('Check Spilt')
# Out:
# Continious Variables:  5
# Categorical Variables:  9
# Total Variables:  14
# Variable Spilt Ties

# %% [markdown]
# ## Examine Continuous Variables

# %%
# taret size
plt.figure(figsize=(12,1))
sns.countplot(y='target', data=df, palette='coolwarm', orient ='h')

# %%
# distribution of continuous variables
df[vars_con].describe().round(0).transpose()
# Out:
#           count   mean   std    min    25%    50%    75%    max
# age       303.0   54.0   9.0   29.0   48.0   55.0   61.0   77.0
# trestbps  303.0  132.0  18.0   94.0  120.0  130.0  140.0  200.0
# chol      303.0  246.0  52.0  126.0  211.0  240.0  274.0  564.0
# thalach   303.0  150.0  23.0   71.0  134.0  153.0  166.0  202.0
# oldpeak   303.0    1.0   1.0    0.0    0.0    1.0    2.0    6.0

# %%
# correlations between variables
sns.heatmap(df[vars_con].corr(),cmap='YlGnBu', annot=True)

# %%
# high level view of continious variables
sns.pairplot(df,vars=vars_con, 
             hue='target', 
             palette='coolwarm',
             kind='reg')

# %%
plt.figure(figsize=(10,6))
df[df['target']==1]['age'].hist(alpha=0.5,color='red',
                                              bins=30,label='target=1')
df[df['target']==0]['age'].hist(alpha=0.5,color='blue',
                                              bins=30,label='target=0')
plt.legend()
plt.xlabel('Age')

# %%
plt.figure(figsize=(10,6))
df[df['target']==1]['trestbps'].hist(alpha=0.5,color='red',
                                              bins=30,label='target=1')
df[df['target']==0]['trestbps'].hist(alpha=0.5,color='blue',
                                              bins=30,label='target=0')
plt.legend()
plt.xlabel('trestbps')

# %%
plt.figure(figsize=(10,6))
df[df['target']==1]['trestbps'].hist(alpha=0.5,color='red',
                                              bins=30,label='target=1')
df[df['target']==0]['trestbps'].hist(alpha=0.5,color='blue',
                                              bins=30,label='target=0')
plt.legend()
plt.xlabel('trestbps')

# %%
plt.figure(figsize=(10,6))
df[df['target']==1]['chol'].hist(alpha=0.5,color='red',
                                              bins=30,label='target=1')
df[df['target']==0]['chol'].hist(alpha=0.5,color='blue',
                                              bins=30,label='target=0')
plt.legend()
plt.xlabel('chol')

# %%
plt.figure(figsize=(10,6))
df[df['target']==1]['thalach'].hist(alpha=0.5,color='red',
                                              bins=30,label='target=1')
df[df['target']==0]['thalach'].hist(alpha=0.5,color='blue',
                                              bins=30,label='target=0')
plt.legend()
plt.xlabel('thalach')

# %%
plt.figure(figsize=(10,6))
df[df['target']==1]['oldpeak'].hist(alpha=0.5,color='red',
                                              bins=30,label='target=1')
df[df['target']==0]['oldpeak'].hist(alpha=0.5,color='blue',
                                              bins=30,label='target=0')
plt.legend()
plt.xlabel('oldpeak')

# %% [markdown]
# ## Examine Categorical Variables

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,3))

sns.countplot(x='sex',data=df,  palette="coolwarm", hue = 'target', ax=axes[0])
sns.countplot(x='cp',data=df,  palette="coolwarm", hue = 'target',ax=axes[1])

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,3))

sns.countplot(x='fbs',data=df,  palette="coolwarm", hue = 'target', ax=axes[0])
sns.countplot(x='restecg',data=df,  palette="coolwarm", hue = 'target', ax=axes[1])

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,3))

sns.countplot(x='exang',data=df,  palette="coolwarm", hue = 'target', ax=axes[0])
sns.countplot(x='slope',data=df,  palette="coolwarm", hue = 'target', ax=axes[1])

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,3))

sns.countplot(x='thal',data=df,  palette="coolwarm", hue = 'target', ax=axes[0])
sns.countplot(x='ca',data=df,  palette="coolwarm", hue = 'target',ax=axes[1])

# %% [markdown]
# ## EDA Findings
#
# Place holder

# %% [markdown]
# # Model Data Preparation

# %% [markdown]
# ## Encode Categorical Variables

# %%
# categorical variables reference
# binary: sex, fbs  exang, target
print('categorical variables:', vars_cat, 
      '\n total: ', len(vars_cat))
# Out:
# categorical variables: ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']
#  total:  9

# %%
# encode categorical variables for model (5 non binary)
# cp, restecg, slope, ca, thal 

a = pd.get_dummies(df['cp'], prefix = 'cp')
b = pd.get_dummies(df['restecg'], prefix = 'restecg')
c = pd.get_dummies(df['slope'], prefix = 'slope')
d = pd.get_dummies(df['ca'], prefix = 'ca')
e = pd.get_dummies(df['thal'], prefix = 'thal')

dummies = [df, a, b, c, d, e]

# add new variables
model_df = pd.concat(dummies, axis = 1) 

# drop non-encoded variables
model_df = model_df.drop(columns = ['cp', 'restecg', 'slope', 'ca', 'thal'])

# %%
# quick data model check on new variables
print(list(model_df.columns))
print(' \n Total Variables: ', len(model_df.columns))
# Out:
# ['age', 'sex', 'trestbps', 'chol', 'fbs', 'thalach', 'exang', 'oldpeak', 'target', 'cp_0', 'cp_1', 'cp_2', 'cp_3', 'restecg_0', 'restecg_1', 'restecg_2', 'slope_0', 'slope_1', 'slope_2', 'ca_0', 'ca_1', 'ca_2', 'ca_3', 'ca_4', 'thal_0', 'thal_1', 'thal_2', 'thal_3']
#
#  Total Variables:  28

# %% [markdown]
# ## Train & Test Data Split

# %%
# split by features and target

from sklearn.model_selection import train_test_split

X = model_df.loc[:, model_df.columns != 'target'] # all except y

y = model_df['target']

# %%
# train test split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# # Machine Learning

# %%
# Evaluaton Metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import roc_curve, auc
import sklearn.metrics as metrics

# %% [markdown]
# ## Logistic Reggression

# %%
# fit logistic reggression model

from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()
clf.fit(X_train,y_train)

clf_predictions = clf.predict(X_test)

# %% [markdown]
# ### Classification Report

# %%
print('Logistic Regression Scores: \n', classification_report(y_test,clf_predictions))
# Out:
# Logistic Regression Scores:
#               precision    recall  f1-score   support
#
#           0       0.93      0.86      0.89        44
#           1       0.88      0.94      0.91        47
#
# avg / total       0.90      0.90      0.90        91

# %% [markdown]
# ### Confusion Matrix

# %%
# Confusion Matrix df
clf_cm = confusion_matrix(y_test, clf_predictions)

clf_cm_df = pd.DataFrame(clf_cm,
                     index = ['Active = 0 ','Active = 1'], 
                     columns = ['Active = 0','Active = 1'])

# %%
# Confusion Matrix Heatmap
plt.figure(figsize=(10,4))
sns.heatmap(clf_cm_df, annot=True)
plt.title('Logistic Regression \n Accuracy: {0:.3f}'.format(accuracy_score(y_test, clf_predictions)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# ### ROC & AUC

# %%
# ROC & AUC

clf_probs = clf.predict_proba(X_test)
clf_preds = clf_probs[:,1]

fpr, tpr, threshold = metrics.roc_curve(y_test, clf_preds)
clf_roc_auc = metrics.auc(fpr, tpr)

# %%
# ROC Plot
plt.title('Logistic Regression ROC')
plt.plot(fpr, tpr, 'c', label = 'AUC = %0.2f' % clf_roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## Random Forest

# %%
# fit random forest 

from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=1000)
rfc.fit(X_train,y_train)

rfc_predictions = rfc.predict(X_test)

# %% [markdown]
# ### Classification Report

# %%
# random forest scores

print('Random Forest: \n', classification_report(y_test,rfc_predictions))
# Out:
# Random Forest:
#               precision    recall  f1-score   support
#
#           0       0.83      0.80      0.81        44
#           1       0.82      0.85      0.83        47
#
# avg / total       0.82      0.82      0.82        91

# %% [markdown]
# ### Confusion Matrix

# %%
# Confusion Matrix df
rfc_cm = confusion_matrix(y_test, rfc_predictions)

rfc_cm_df = pd.DataFrame(rfc_cm,
                     index = ['Active = 0 ','Active = 1'], 
                     columns = ['Active = 0','Active = 1'])

# %%
# Confusion Matrix Heatmap
plt.figure(figsize=(10,4))
sns.heatmap(rfc_cm_df, annot=True)
plt.title('Random Forest \n Accuracy: {0:.3f}'.format(accuracy_score(y_test, rfc_predictions)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# ### ROC & AUC

# %%
rfc_probs = rfc.predict_proba(X_test)
rfc_preds = rfc_probs[:,1]

fpr, tpr, threshold = metrics.roc_curve(y_test, rfc_preds)
roc_auc = metrics.auc(fpr, tpr)

# %%
plt.title('Random Forest ROC')
plt.plot(fpr, tpr, 'c', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# #  Results Summary

# %%
# logistic regression metrics summary 
clf_accuracy = metrics.accuracy_score(y_test, clf_predictions)
clf_precision = metrics.precision_score(y_test, clf_predictions)   
clf_recall =  metrics.recall_score(y_test, clf_predictions)
clf_f1 = metrics.f1_score(y_test, clf_predictions)
clf_auc = metrics.roc_auc_score(y_test, clf_predictions)

# %%
# logistic regression scores

clf_results = {'Accuracy': [clf_accuracy], 
               'Precision': [clf_precision],
               'Recall': [clf_recall],
               'F1': [clf_f1],
               'AUC': [clf_auc]}
               
clf_results_df = pd.DataFrame(clf_results)

# %%
# Random Forest metrics summary 
rfc_accuracy = metrics.accuracy_score(y_test, rfc_predictions)
rfc_precision = metrics.precision_score(y_test, rfc_predictions)   
rfc_recall =  metrics.recall_score(y_test, rfc_predictions)
rfc_f1 = metrics.f1_score(y_test, rfc_predictions)
rfc_auc = metrics.roc_auc_score(y_test, rfc_predictions)

# %%
# Random Forest scores , orient ='h'

rfc_results = {'Accuracy': [rfc_accuracy], 
               'Precision': [rfc_precision],
               'Recall': [rfc_recall],
               'F1': [rfc_f1],            
               'AUC': [rfc_auc]}
               
rfc_results_df = pd.DataFrame(rfc_results)

# %%
clf_results_df['Model'] = 'LogReg'
rfc_results_df['Model'] ='RanForest'

# %%
all_results = pd.concat([clf_results_df,rfc_results_df])
all_results.set_index('Model', inplace=True )

# %% [markdown]
# ## 70/30 Split Performance Summary

# %%
plt.figure(figsize=(14,2.5))
sns.heatmap(all_results.round(2), annot=True)
plt.title('Total Performance')
plt.ylabel('')
plt.xlabel('Scores')

# %% [markdown]
# ## K-Fold Performance

# %%
from sklearn.cross_validation import cross_val_score, cross_val_predict

# run models
k_folds = 10
clf_kfold_scores = cross_val_score(clf, X, y, cv=k_folds)
rfc_kfold_scores = cross_val_score(rfc, X, y, cv=k_folds)

# results
s1 = pd.Series(clf_kfold_scores, name='LogReg')
s2 = pd.Series(rfc_kfold_scores, name='RanForest')

# %%
plt.figure(figsize=(14,5))

ax = plt.axes()
x = np.linspace(0, 10)

ax.plot(s1)
ax.plot(s2)

plt.title('Cross Validation Performance')
plt.ylabel('Scores')
plt.xlabel('K-Folds')
plt.legend()
